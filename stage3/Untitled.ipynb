# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model('../VGG16_Deepfake.keras')

# %%
print(model)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# ...
# Total params: 14,847,297
# Trainable params: 132,097
# Non-trainable params: 14,715,200
# _________________________________________________________________

# %%
dir(model)
# Out:
# ['_SCALAR_UPRANKING_ON',
#  '_TF_MODULE_IGNORED_PROPERTIES',
#  '__call__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activity_regularizer',
#  '_add_trackable',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_assert_compile_was_called',
#  '_assert_weights_created',
#  '_auto_track_sub_layers',
#  '_autocast',
#  '_autographed_call',
#  '_base_model_initialized',
#  '_build_input_shape',
#  '_call_spec',
#  '_callable_losses',
#  '_captured_weight_regularizer',
#  '_cast_single_input',
#  '_check_call_args',
# ...

# %%
from PIL import Image
image = Image.open('../test/fake/120.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
print(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224 at 0x1CCB6A960D0>

# %%
import numpy as np
im_arr = np.array(image)
im_arr.shape
# Out:
# (224, 224, 3)

# %%
im_arr = im_arr.astype('float32')/255.0
im_arr.shape
# Out:
# (224, 224, 3)

# %%
im_arr
# Out:
# array([[[0.6117647 , 0.44705883, 0.12941177],
#         [0.60784316, 0.44705883, 0.13333334],
#         [0.60784316, 0.45490196, 0.13725491],
#         ...,
#         [0.47843137, 0.3254902 , 0.2784314 ],
#         [0.47058824, 0.3254902 , 0.27450982],
#         [0.44313726, 0.31764707, 0.2627451 ]],
#
#        [[0.6117647 , 0.44705883, 0.12941177],
#         [0.60784316, 0.44705883, 0.12941177],
#         [0.60784316, 0.45490196, 0.13333334],
#         ...,
#         [0.48235294, 0.32941177, 0.28235295],
#         [0.47058824, 0.3254902 , 0.27450982],
#         [0.44313726, 0.3137255 , 0.2627451 ]],
#
#        [[0.6117647 , 0.44705883, 0.12941177],
#         [0.60784316, 0.4509804 , 0.12941177],
#         [0.60784316, 0.45490196, 0.13333334],
#         ...,
#         [0.48235294, 0.32941177, 0.28235295],
#         [0.4745098 , 0.3254902 , 0.2784314 ],
#         [0.45490196, 0.31764707, 0.26666668]],
#
#        ...,
#
#        [[0.10588235, 0.08235294, 0.10196079],
# ...

# %%
im_arr.shape
im_arr = np.expand_dims(im_arr, axis=0)
im_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
res = model.predict(im_arr)
# Out:
# 1/1 [==============================] - 0s 360ms/step

# %%
res
# Out:
# array([[0.9756616]], dtype=float32)

# %%
res
# Out:
# array([[0.0825829]], dtype=float32)

# %%
from PIL import Image
import numpy as np
image = Image.open('../OF/test/1.')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
im_arr = np.array(image)
im_arr = tf.keras.applications.mobilenet_v2.preprocess_input(im_arr)
im_arr = np.expand_dims(im_arr, axis=0)
res = model.predict(im_arr)
res
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[0.42342344]], dtype=float32)

# %%
import numpy as np
from PIL import Image

# Ваш текущий код с диагностикой
image = Image.open('../test/fake/9970.png')
im_arr = np.array(image)

print(f"1. Форма изображения после загрузки: {im_arr.shape}")
print(f"2. Размер изображения: {image.size}")
print(f"3. Режим изображения: {image.mode}")
print(f"4. Минимальное значение: {im_arr.min()}")
print(f"5. Максимальное значение: {im_arr.max()}")

# %%
frames = from_video2array('../DeepfakeTIMIT/lower_quality/mrjo0/si1624-video-mstk0.avi')

# %%
frames.shape
# Out:
# (77, 224, 224, 3)
